# %%
import pandas as pd
from IPython.display import HTML

df = pd.read_csv("cities.csv")
df.head(5)
# Out:
#         City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 0    rikitea        51.0      PF  1.566718e+09      72.0 -23.12 -134.97
# 1    ushuaia         0.0      AR  1.566718e+09      86.0 -54.81  -68.31
# 2    diapaga        98.0      BF  1.566718e+09      75.0  12.07    1.79
# 3  hithadhoo        95.0      MV  1.566718e+09      72.0  -0.60   73.08
# 4    mandera        14.0      ET  1.566718e+09      52.0   3.94   41.86
#
#    Max Temp  Wind Speed
# 0     69.42       18.19
# 1     39.20        3.36
# 2     77.88       11.07
# 3     82.66        9.89
# 4     82.12       18.75

# %%
HTML(df.to_html(classes='table-responsive-md table-striped table-hover'))
# Out:
# <table border="1" class="dataframe table-responsive-md table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>rikitea</td>
#       <td>51.0</td>
#       <td>PF</td>
#       <td>1.566718e+09</td>
#       <td>72.0</td>
#       <td>-23.12</td>
#       <td>-134.97</td>
#       <td>69.42</td>
#       <td>18.19</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ushuaia</td>
#       <td>0.0</td>
#       <td>AR</td>
#       <td>1.566718e+09</td>
#       <td>86.0</td>
#       <td>-54.81</td>
#       <td>-68.31</td>
#       <td>39.20</td>
#       <td>3.36</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>diapaga</td>
#       <td>98.0</td>
# ...

# %%
data = df.to_html(classes='table-responsive-md table-striped table-hover')

# %%
with open('CityData.html', 'w') as f:
    f.write(data)
